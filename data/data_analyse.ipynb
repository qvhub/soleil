# %%
import matplotlib.pyplot as plt

import seaborn as sns

import numpy as np

import pandas as pd

import time

import time

# %% [markdown]
# # D A T A
# # R E D D I T

# %% [markdown]
# # Ouverture du csv généré par le craping du site reddit pour la recherche des 'Mercredi Tech'

# %%
df_r = pd.read_csv('tech_reddit.csv')
display(df_r.head())
# Out:
#                         date                       title     points  \
# 0  2021-01-13T06:02:54+00:00  Mercredi Tech - 2021-01-13  15 points
# 1  2021-01-06T07:17:13+00:00  Mercredi Tech - 2021-01-06  18 points
# 2  2020-12-30T05:56:05+00:00  Mercredi Tech - 2020-12-30  17 points
# 3  2020-12-23T07:06:42+00:00  Mercredi Tech - 2020-12-23  15 points
# 4  2020-12-16T07:03:31+00:00  Mercredi Tech - 2020-12-16  14 points
#
#            comments
# 0  227 commentaires
# 1  194 commentaires
# 2  152 commentaires
# 3  173 commentaires
# 4  171 commentaires

# %%
display(df_r['date'].astype(str))
# Out:
# 0     2021-01-13T06:02:54+00:00
# 1     2021-01-06T07:17:13+00:00
# 2     2020-12-30T05:56:05+00:00
# 3     2020-12-23T07:06:42+00:00
# 4     2020-12-16T07:03:31+00:00
#                 ...
# 85    2019-02-27T08:31:04+00:00
# 86    2019-02-13T08:09:39+00:00
# 87    2018-11-19T12:12:15+00:00
# 88    2018-09-19T06:59:33+00:00
# 89    2018-09-05T07:12:03+00:00
# Name: date, Length: 90, dtype: object

# %%
df_r['date'] = df_r['date'].astype(str)

df_r['date'] = df_r['date'].str[:10]

display(df_r['date'])
# Out:
# 0     2021-01-13
# 1     2021-01-06
# 2     2020-12-30
# 3     2020-12-23
# 4     2020-12-16
#          ...
# 85    2019-02-27
# 86    2019-02-13
# 87    2018-11-19
# 88    2018-09-19
# 89    2018-09-05
# Name: date, Length: 90, dtype: object

# %%
df_r['date'] = pd.to_datetime(df_r['date'], format="%Y-%m-%d")
df_r['date']
# Out:
# 0    2021-01-13
# 1    2021-01-06
# 2    2020-12-30
# 3    2020-12-23
# 4    2020-12-16
#         ...
# 85   2019-02-27
# 86   2019-02-13
# 87   2018-11-19
# 88   2018-09-19
# 89   2018-09-05
# Name: date, Length: 90, dtype: datetime64[ns]

# %%
df_r['points'] = df_r['points'].str.replace('points', '')
df_r['points'] = df_r['points'].astype(int)

# %%
df_r['comments'] = df_r['comments'].str.replace('comments', '')
df_r['comments'] = df_r['comments'].str.replace('comment', '')
df_r['comments'] = df_r['comments'].str.replace('aires', '')
df_r['comments'] = df_r['comments'].str.replace('aire', '')

df_r['comments'] = df_r['comments'].astype(str)
df_r['comments'] = df_r['comments'].astype(int)

display(df_r['comments'])
# Out:
# 0     227
# 1     194
# 2     152
# 3     173
# 4     171
#      ...
# 85    116
# 86    151
# 87      5
# 88    112
# 89    478
# Name: comments, Length: 90, dtype: int64

# %%
display(df_r)
# Out:
#          date                                              title  points  \
# 0  2021-01-13                         Mercredi Tech - 2021-01-13      15
# 1  2021-01-06                         Mercredi Tech - 2021-01-06      18
# 2  2020-12-30                         Mercredi Tech - 2020-12-30      17
# 3  2020-12-23                         Mercredi Tech - 2020-12-23      15
# 4  2020-12-16                         Mercredi Tech - 2020-12-16      14
# ..        ...                                                ...     ...
# 85 2019-02-27  Mercredi TechSupport/conseil à l'achat - AirFr...      12
# 86 2019-02-13  Mercredi TechSupport/conseil à l'achat - AirFr...      27
# 87 2018-11-19  [AMA] FibreTigre (Game Designer, Scénariste, C...      51
# 88 2018-09-19           Mercredi TechSupport - sudo apt-get rekt      43
# 89 2018-09-05      Mercredi TechSupport - Quand ça rate, formate     170
#
#     comments
# 0        227
# 1        194
# 2        152
# 3        173
# 4        171
# ..       ...
# 85       116
# 86       151
# 87         5
# 88       112
# 89       478
#
# [90 rows x 4 columns]

# %% [markdown]
# # D A T A
# # W E A T H E R

# %% [markdown]
# # Ouverture du csv généré par le craping du site reddit pour la recherche des 'Mercredi Tech'

# %%
df_w = pd.read_csv('result_data_weather.csv')

display(df_w.head())
# Out:
#    Unnamed: 0 current_day  clound_min  clound_max  clound_std  clound_median
# 0           0    2019-1-1         1.0         4.0    1.356801            1.0
# 1           1    2019-1-2         1.0         4.0    1.403459            1.5
# 2           2    2019-1-3         1.0         4.0    1.435481            3.0
# 3           3    2019-1-4         1.0         4.0    1.435481            3.0
# 4           4    2019-1-5         1.0         4.0    1.477098            1.0

# %%
df_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     731 non-null    int64
#  1   current_day    731 non-null    object
#  2   clound_min     731 non-null    float64
#  3   clound_max     731 non-null    float64
#  4   clound_std     731 non-null    float64
#  5   clound_median  731 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 34.4+ KB

# %%
#df_r['date'] = df_r['date'].astype(str).str[5]

display(df_r['date'])
# Out:
# 0    2021-01-13
# 1    2021-01-06
# 2    2020-12-30
# 3    2020-12-23
# 4    2020-12-16
#         ...
# 85   2019-02-27
# 86   2019-02-13
# 87   2018-11-19
# 88   2018-09-19
# 89   2018-09-05
# Name: date, Length: 90, dtype: datetime64[ns]

# %%
df_w = pd.read_csv('result_data_weather.csv',  index_col=0)

# %%
display(df_w)
# Out:
#     current_day  clound_min  clound_max  clound_std  clound_median
# 0      2019-1-1         1.0         4.0    1.356801            1.0
# 1      2019-1-2         1.0         4.0    1.403459            1.5
# 2      2019-1-3         1.0         4.0    1.435481            3.0
# 3      2019-1-4         1.0         4.0    1.435481            3.0
# 4      2019-1-5         1.0         4.0    1.477098            1.0
# ..          ...         ...         ...         ...            ...
# 726  2020-12-27         0.0         4.0    1.556998            2.0
# 727  2020-12-28         1.0         4.0    1.167748            2.0
# 728  2020-12-29         1.0         4.0    1.167748            2.0
# 729  2020-12-30         1.0         4.0    1.240112            2.0
# 730  2020-12-31         1.0         4.0    1.138180            2.0
#
# [731 rows x 5 columns]

# %%
df_w = df_w.rename(columns={"current_day": "date"})

df_w['date'] = pd.to_datetime(df_w['date'], format="%Y-%m-%d")

df_w
# Out:
#           date  clound_min  clound_max  clound_std  clound_median
# 0   2019-01-01         1.0         4.0    1.356801            1.0
# 1   2019-01-02         1.0         4.0    1.403459            1.5
# 2   2019-01-03         1.0         4.0    1.435481            3.0
# 3   2019-01-04         1.0         4.0    1.435481            3.0
# 4   2019-01-05         1.0         4.0    1.477098            1.0
# ..         ...         ...         ...         ...            ...
# 726 2020-12-27         0.0         4.0    1.556998            2.0
# 727 2020-12-28         1.0         4.0    1.167748            2.0
# 728 2020-12-29         1.0         4.0    1.167748            2.0
# 729 2020-12-30         1.0         4.0    1.240112            2.0
# 730 2020-12-31         1.0         4.0    1.138180            2.0
#
# [731 rows x 5 columns]

# %% [markdown]
# # D A T A S E T
# # R E D D I T | & | W E A T H E R

# %%
#df_rw = pd.join([df_r, df_w], keys="date")
#df_rw = pd.merge([df_r, df_w], on='key')
df_rw = pd.merge(df_r, df_w, on='date', how='left')

# %%
display(df_rw)
# Out:
#          date                                              title  points  \
# 0  2021-01-13                         Mercredi Tech - 2021-01-13      15
# 1  2021-01-06                         Mercredi Tech - 2021-01-06      18
# 2  2020-12-30                         Mercredi Tech - 2020-12-30      17
# 3  2020-12-23                         Mercredi Tech - 2020-12-23      15
# 4  2020-12-16                         Mercredi Tech - 2020-12-16      14
# ..        ...                                                ...     ...
# 85 2019-02-27  Mercredi TechSupport/conseil à l'achat - AirFr...      12
# 86 2019-02-13  Mercredi TechSupport/conseil à l'achat - AirFr...      27
# 87 2018-11-19  [AMA] FibreTigre (Game Designer, Scénariste, C...      51
# 88 2018-09-19           Mercredi TechSupport - sudo apt-get rekt      43
# 89 2018-09-05      Mercredi TechSupport - Quand ça rate, formate     170
#
#     comments  clound_min  clound_max  clound_std  clound_median
# 0        227         NaN         NaN         NaN            NaN
# 1        194         NaN         NaN         NaN            NaN
# 2        152         1.0         4.0    1.240112            2.0
# 3        173         1.0         4.0    0.887625            1.5
# 4        171         1.0         4.0    1.477098            1.0
# ..       ...         ...         ...         ...            ...
# 85       116         4.0         4.0    0.000000            4.0
# 86       151         1.0         4.0    1.356801            4.0
# 87         5         NaN         NaN         NaN            NaN
# 88       112         NaN         NaN         NaN            NaN
# 89       478         NaN         NaN         NaN            NaN
#
# [90 rows x 8 columns]

# %%
df_rw.reset_index(drop=True, inplace=True)
df_rw.dropna()
# Out:
#          date                                              title  points  \
# 2  2020-12-30                         Mercredi Tech - 2020-12-30      17
# 3  2020-12-23                         Mercredi Tech - 2020-12-23      15
# 4  2020-12-16                         Mercredi Tech - 2020-12-16      14
# 5  2020-12-09  le Gentil Organisateur des Mercredi Tech /u/Ch...      12
# 6  2020-12-09                         Mercredi Tech - 2020-12-09      19
# ..        ...                                                ...     ...
# 82 2019-07-31                                      Mercredi Tech      31
# 83 2019-06-12             Mercredi TechSupport/conseil à l'achat      21
# 84 2019-06-05             Mercredi TechSupport/conseil à l'achat      24
# 85 2019-02-27  Mercredi TechSupport/conseil à l'achat - AirFr...      12
# 86 2019-02-13  Mercredi TechSupport/conseil à l'achat - AirFr...      27
#
#     comments  clound_min  clound_max  clound_std  clound_median
# 2        152         1.0         4.0    1.240112            2.0
# 3        173         1.0         4.0    0.887625            1.5
# 4        171         1.0         4.0    1.477098            1.0
# 5          1         1.0         4.0    1.497473            1.5
# 6        230         1.0         4.0    1.497473            1.5
# ..       ...         ...         ...         ...            ...
# 82       215         1.0         4.0    1.167748            4.0
# 83        72         1.0         4.0    1.356801            3.0
# 84       151         1.0         4.0    1.164500            4.0
# 85       116         4.0         4.0    0.000000            4.0
# 86       151         1.0         4.0    1.356801            4.0
#
# [85 rows x 8 columns]

# %%
df_rw.describe()
# Out:
#            points    comments  clound_min  clound_max  clound_std  \
# count   90.000000   90.000000   85.000000        85.0   85.000000
# mean    24.588889  163.366667    1.411765         4.0    1.093657
# std     33.591363   72.238595    1.026948         0.0    0.468902
# min      2.000000    1.000000    0.000000         4.0    0.000000
# 25%     13.000000  125.000000    1.000000         4.0    0.996205
# 50%     15.000000  162.000000    1.000000         4.0    1.240112
# 75%     19.000000  201.750000    1.000000         4.0    1.378954
# max    238.000000  478.000000    4.000000         4.0    1.566699
#
#        clound_median
# count      85.000000
# mean        3.029412
# std         1.100197
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         4.000000
# max         4.000000

# %%
df_rw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           90 non-null     datetime64[ns]
#  1   title          90 non-null     object
#  2   points         90 non-null     int64
#  3   comments       90 non-null     int64
#  4   clound_min     85 non-null     float64
#  5   clound_max     85 non-null     float64
#  6   clound_std     85 non-null     float64
#  7   clound_median  85 non-null     float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 5.8+ KB

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_rw.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))
sns.pairplot(df_rw)

# %%
df_rw.hist(figsize=(10,10)) 
plt.tight_layout()
plt.show()
